# %%
# %load_ext autoreload
# %autoreload 2

# %%
import equinox as eqx
import esm  # pip install fair-esm==2.0.0
import esm2quinox
import jax.random as jrandom
import optax  # pip install optax
from dataset import initialize_datasets
from model import AFF_PREDICTOR
from training import train_model, eval_step
import jax.numpy as jnp
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import jax.random as jr
import jax

# %%
# initialize the dataloader
train_loader, val_loader, test_loader = initialize_datasets(
    paths=[
        "/home/kunzj/dataset/final_csv/train.csv",
        "/home/kunzj/dataset/final_csv/validation.csv",
        "/home/kunzj/dataset/final_csv/test.csv",
    ],
    batches=[5, 3, 1],
)

# %%
train_loader.dataset.__len__()
# Out:
# 885

# %%
sns.displot(test_loader.dataset.aff_Vals)

# %%
for x1,x2,y in train_loader:
    x1 = jnp.array(x1)
    x2=jnp.array(x2)
    break

# %%
# generating keys
model_key, call_key= jr.split(jrandom.PRNGKey(0), 2)

# initializing models
torch_model, _ = esm.pretrained.esm2_t6_8M_UR50D()
model_esm2 = esm2quinox.from_torch(torch_model)
model_aff, state = eqx.nn.make_with_state(AFF_PREDICTOR)(
    model=model_esm2, key=model_key
)

# initializing optimizer
optim = optax.adam(learning_rate=0.001)
opt_state = optim.init(eqx.filter(model_aff, eqx.is_inexact_array))

# %%
model_key, call_key= jr.split(jrandom.PRNGKey(0), 2)
call_key_split = jr.split(call_key,num= x1.shape[0])

# %%
call_key_split.shape
# Out:
# (5, 2)

# %%
x1.shape
# Out:
# (5, 992)

# %%
import equinox as eqx

# %%
drop =eqx.nn.Dropout(0.1)

# %%
eqx.nn.Linear(in_features=992)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 drop()
#
# File ~/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/contextlib.py:81, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      78 @wraps(func)
#      79 def inner(*args, **kwds):
#      80     with self._recreate_cm():
# ---> 81         return func(*args, **kwds)
#
# TypeError: Dropout.__call__() missing 1 required positional argument: 'x'

# %%
jax.vmap(drop, axis_name="batch", in_axes=(0, None), out_axes=(0, None))(
        x1, call_key_split[:,0]
    )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 jax.vmap(drop, axis_name="batch", in_axes=(0, None), out_axes=(0, None))(
#       2         x1, call_key_split[:,0]
#       3     )
#
#     [... skipping hidden 7 frame]
#
# File ~/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/contextlib.py:81, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      78 @wraps(func)
#      79 def inner(*args, **kwds):
#      80     with self._recreate_cm():
# ---> 81         return func(*args, **kwds)
#
# TypeError: Dropout.__call__() takes 2 positional arguments but 3 were given

# %%
jax.vampdrop(x1,call_key_split[:,0].squeeze())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 drop(x1,call_key_split[:,0].squeeze())
#
# File ~/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/contextlib.py:81, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      78 @wraps(func)
#      79 def inner(*args, **kwds):
#      80     with self._recreate_cm():
# ---> 81         return func(*args, **kwds)
#
# TypeError: Dropout.__call__() takes 2 positional arguments but 3 were given

# %%
call_key_split = jr.split(call_key, x1.shape[0])
jax.vmap(model_aff)(
        x1, x2, call_key_split[:,0].squeeze())
# Out:
# (320, 992)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 call_key_split = jr.split(call_key, x1.shape[0])
# ----> 2 jax.vmap(model_aff)(
#       3         x1, x2, call_key_split[:,0].squeeze())
#
#     [... skipping hidden 7 frame]
#
# File ~/BindCraft_uva_internship/notebooks/model.py:199, in AFF_PREDICTOR.__call__(self, tokens_prot, tokens_pept, key)
#     197 for layer in self.cnn_stack:
#     198     if isinstance(layer, eqx.nn.Dropout):
# --> 199         x = layer(x, key)
#     200     else:
#     201         x = layer(x)
#
# File ~/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/contextlib.py:81, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      78 @wraps(func)
#      79 def inner(*args, **kwds):
#      80     with self._recreate_cm():
# ---> 81         return func(*args, **kwds)
#
# TypeError: Dropout.__call__() takes 2 positional arguments but 3 were given

# %%
# train model
best_model, best_state, train_losses, val_losses = train_model(
    training_DataLoader=train_loader,
    validation_Dataloader=val_loader,
    max_epochs=50,
    model_aff=model_aff,
    key= call_key,
    opt_state=opt_state,
    optim=optim,
)
# Out:
# Epochs:   0%|          | 0/50 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 # train model
# ----> 2 best_model, best_state, train_losses, val_losses = train_model(
#       3     training_DataLoader=train_loader,
#       4     validation_Dataloader=val_loader,
#       5     max_epochs=50,
#       6     model_aff=model_aff,
#       7     key= call_key,
#       8     opt_state=opt_state,
#       9     optim=optim,
#      10 )
#
# File ~/BindCraft_uva_internship/notebooks/training.py:110, in train_model(training_DataLoader, validation_Dataloader, max_epochs, model_aff, key, opt_state, optim)
#     106 for x_prot, x_pept, y in tqdm.tqdm(
#     107     training_DataLoader, desc="Training-Set", position=1, leave=False
#     108 ):
#     109     x_prot, x_pept, y = jnp.array(x_prot), jnp.array(x_pept), jnp.array(y)
# --> 110     loss, model_aff, opt_state = make_step(
#     111         model_aff, x_prot, x_pept, y, opt_state, optim, key
#     112     )
#     113 train_losses.append(loss.item())
#     115 # ---- VALIDATION ----
#
#     [... skipping hidden 18 frame]
#
# File ~/BindCraft_uva_internship/notebooks/training.py:66, in make_step(model, x_prot, x_pept, y, opt_state, optim, key)
#      47 @eqx.filter_jit
#      48 def make_step(model, x_prot, x_pept, y, opt_state, optim, key):
#      49     """
#      50     Gradient update step
#      51
#    (...)     64         updated optimizer state
#      65     """
# ---> 66     (loss, state), grads = compute_loss(model, x_prot, x_pept, y, key)
#      67     updates, opt_state = optim.update(grads, opt_state)
#      68     model = eqx.apply_updates(model, updates)
#
#     [... skipping hidden 12 frame]
#
# File ~/BindCraft_uva_internship/notebooks/training.py:21, in compute_loss(model, x_prot, x_pept, y, key)
#       7 @eqx.filter_value_and_grad(has_aux=True)
#       8 def compute_loss(model, x_prot, x_pept, y, key):
#       9     """
#      10     Computes loss batched with vmap across first axis
#      11
#    (...)     19         updated model state
#      20     """
# ---> 21     pred_y = jax.vmap(model, axis_name="batch", in_axes=(0, None), out_axes=(0, None))(
#      22         x_prot, x_pept, key
#      23     )
#      24     loss = jnp.mean((pred_y - y) ** 2)
#      26     return loss
#
#     [... skipping hidden 1 frame]
#
# File ~/venv/esm2/lib/python3.12/site-packages/jax/_src/api.py:1087, in vmap.<locals>.vmap_f(*args, **kwargs)
#    1083 @wraps(fun, docstr=docstr)
#    1084 @api_boundary
#    1085 def vmap_f(*args, **kwargs):
#    1086   if isinstance(in_axes, tuple) and len(in_axes) != len(args):
# -> 1087     raise ValueError("vmap in_axes must be an int, None, or a tuple of entries corresponding "
#    1088                      "to the positional arguments passed to the function, "
#    1089                      f"but got {len(in_axes)=}, {len(args)=}")
#    1091   args_flat, in_tree  = tree_flatten((args, kwargs), is_leaf=batching.is_vmappable)
#    1092   dbg = debug_info("vmap", fun, args, kwargs)
#
# ValueError: vmap in_axes must be an int, None, or a tuple of entries corresponding to the positional arguments passed to the function, but got len(in_axes)=2, len(args)=3

# %%
inference_model = eqx.nn.inference_mode(best_model)
inference_model = eqx.Partial(inference_model, state=best_state)
test_loss_list = []

for entry, (x_val, y_val) in enumerate(test_loader):
    x_val, y_val = jnp.array(x_val), jnp.array(y_val)
    test_loss, pred_y = eval_step(inference_model, x_val, y_val)
    test_loss_list.append(test_loss.item())


    print(
        f"[Entry {entry + 1}] , Test Loss: {test_loss:.6f}, Predicted Y: {pred_y.item():.6f}, , True Y: {y_val.item():.6f}"
    )
# Out:
# [Entry 1] , Test Loss: 0.065856, Predicted Y: 0.248743, , True Y: 0.505367
# [Entry 2] , Test Loss: 0.016682, Predicted Y: 0.253648, , True Y: 0.382808
# [Entry 3] , Test Loss: 0.042441, Predicted Y: 0.247773, , True Y: 0.453784
# [Entry 4] , Test Loss: 0.093420, Predicted Y: 0.235696, , True Y: 0.541342
# [Entry 5] , Test Loss: 0.082488, Predicted Y: 0.258706, , True Y: 0.545913
# [Entry 6] , Test Loss: 0.077859, Predicted Y: 0.249420, , True Y: 0.528453
# [Entry 7] , Test Loss: 0.218737, Predicted Y: 0.245512, , True Y: 0.713205
# [Entry 8] , Test Loss: 0.115143, Predicted Y: 0.254479, , True Y: 0.593806
# [Entry 9] , Test Loss: 0.019515, Predicted Y: 0.264105, , True Y: 0.403799
# [Entry 10] , Test Loss: 0.130656, Predicted Y: 0.255729, , True Y: 0.617192
# [Entry 11] , Test Loss: 0.108379, Predicted Y: 0.253165, , True Y: 0.582374
# [Entry 12] , Test Loss: 0.045518, Predicted Y: 0.245922, , True Y: 0.459271
# [Entry 13] , Test Loss: 0.034872, Predicted Y: 0.245541, , True Y: 0.432282
# [Entry 14] , Test Loss: 0.030127, Predicted Y: 0.238643, , True Y: 0.412215
# [Entry 15] , Test Loss: 0.030127, Predicted Y: 0.238643, , True Y: 0.412215
# [Entry 16] , Test Loss: 0.249393, Predicted Y: 0.257564, , True Y: 0.756957
# [Entry 17] , Test Loss: 0.254078, Predicted Y: 0.252895, , True Y: 0.756957
# [Entry 18] , Test Loss: 0.201770, Predicted Y: 0.241632, , True Y: 0.690820
# [Entry 19] , Test Loss: 0.209847, Predicted Y: 0.253721, , True Y: 0.711812
# [Entry 20] , Test Loss: 0.006422, Predicted Y: 0.249278, , True Y: 0.329417
# [Entry 21] , Test Loss: 0.067314, Predicted Y: 0.251301, , True Y: 0.510751
# [Entry 90] , Test Loss: 0.041208, Predicted Y: 0.257165, , True Y: 0.460162
# [Entry 91] , Test Loss: 0.165137, Predicted Y: 0.242140, , True Y: 0.648511
# [Entry 92] , Test Loss: 0.026393, Predicted Y: 0.252359, , True Y: 0.414817
# [Entry 93] , Test Loss: 0.049104, Predicted Y: 0.242997, , True Y: 0.464591
# [Entry 94] , Test Loss: 0.039110, Predicted Y: 0.258673, , True Y: 0.456436
# [Entry 95] , Test Loss: 0.064911, Predicted Y: 0.257015, , True Y: 0.511791

# %%
y_train = []
for x,y in train_loader:
    y_train.append(y)

# %%
y_all = []
for y in y_train:
    y_all.extend(np.array(y.flatten()))
# Out:
# /tmp/ipykernel_406096/2146560178.py:3: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   y_all.extend(np.array(y.flatten()))

# %%
y_all
# Out:
# [np.float64(0.4069616835782524),
#  np.float64(0.4069616835782524),
#  np.float64(0.9010508577242694),
#  np.float64(0.8000967927132779),
#  np.float64(0.5538909499477096),
#  np.float64(0.3689813300279721),
#  np.float64(0.5053665428679168),
#  np.float64(0.3828079044711987),
#  np.float64(0.3994695867475277),
#  np.float64(0.6338537778051306),
#  np.float64(0.6653192421932691),
#  np.float64(0.7264684424683591),
#  np.float64(0.44894415788539316),
#  np.float64(0.6120487959478913),
#  np.float64(0.7710305728610859),
#  np.float64(0.7376429506492244),
#  np.float64(0.7376429506492244),
#  np.float64(0.7376429506492244),
#  np.float64(0.49996958344027254),
#  np.float64(0.5459125425336969),
#  np.float64(0.5459125425336969),
#  np.float64(0.5854195853931574),
#  np.float64(0.654845014958701),
#  np.float64(0.5459125425336969),
#  np.float64(0.5392341904066411),
#  np.float64(0.5392341904066411),
#  np.float64(0.8064312703257802),
#  np.float64(0.567717524390936),
#  np.float64(0.7161412378045321),
#  np.float64(0.7161412378045321),
#  np.float64(0.4752057202687418),
#  np.float64(0.4752057202687418),
#  np.float64(0.49408917414601716),
#  np.float64(0.49408917414601716),
#  np.float64(0.7498084768717438),
#  np.float64(0.4656058401617222),
#  np.float64(0.3784783495939574),
#  np.float64(0.8173497479918711),
#  np.float64(0.5284529174245675),
#  np.float64(0.7661262846335193),
#  np.float64(0.7946096186178142),
#  np.float64(0.7461754262058412),
#  np.float64(0.6023985878925266),
#  np.float64(0.8725675237399746),
#  np.float64(0.5938064278451166),
#  np.float64(0.4037991416247691),
#  np.float64(0.4037991416247691),
#  np.float64(0.4037991416247691),
#  np.float64(0.4037991416247691),
#  np.float64(0.5731108793481874),
#  np.float64(0.654845014958701),
#  np.float64(0.579539176098902),
#  np.float64(0.7010304099452171),
#  np.float64(0.7010304099452171),
#  np.float64(0.5413419736829362),
#  np.float64(0.6736144805113251),
#  np.float64(0.6736144805113251),
#  np.float64(0.624684192359526),
#  np.float64(0.596200858375231),
#  np.float64(0.5239656166158493),
#  np.float64(0.5300646049610367),
#  np.float64(0.6171920955288014),
#  np.float64(0.6299372190141437),
#  np.float64(0.6623371117894256),
#  np.float64(0.6623371117894256),
#  np.float64(0.6623371117894256),
#  np.float64(0.8800596205706991),
#  np.float64(0.5261480461700497),
#  np.float64(0.5261480461700497),
#  np.float64(0.5041239023816501),
#  np.float64(0.5041239023816501),
#  np.float64(0.5041239023816501),
#  np.float64(0.5041239023816501),
#  np.float64(0.5041239023816501),
#  np.float64(0.5768871098365406),
#  np.float64(0.5638009655999492),
#  np.float64(0.5353176316156544),
#  np.float64(0.5353176316156544),
#  np.float64(0.4220195815328088),
#  np.float64(0.4220195815328088),
#  np.float64(0.49576666276089726),
#  np.float64(0.5602254275602115),
#  np.float64(0.5861788708715666),
#  np.float64(0.3591646010552669),
#  np.float64(0.44963480884343693),
#  np.float64(0.40863917219313234),
#  np.float64(0.4460786222355083),
#  np.float64(0.5435637452838824),
#  np.float64(0.5435637452838824),
#  np.float64(0.5435637452838824),
#  np.float64(0.4783509636470644),
#  np.float64(0.4817570467469294),
#  np.float64(0.4817570467469294),
#  np.float64(0.710464258453893),
#  np.float64(0.707895124136304),
#  np.float64(0.707895124136304),
#  np.float64(0.5125354970267201),
#  np.float64(0.43415065024911836),
#  np.float64(0.33472644181887057),
#  np.float64(0.4069616835782524),
#  np.float64(0.36769707661188383),
#  np.float64(0.7227301605933817),
#  np.float64(0.5302293056411866),
#  np.float64(0.5302293056411866),
#  np.float64(0.4446146030081518),
#  np.float64(0.6908204457737204),
#  np.float64(0.6908204457737204),
#  np.float64(0.42161844311932056),
#  np.float64(0.42161844311932056),
#  np.float64(0.426605496258425),
#  np.float64(0.44894415788539316),
#  np.float64(0.49692428197911964),
#  np.float64(0.49692428197911964),
#  np.float64(0.49692428197911964),
#  np.float64(0.42934602921736004),
#  np.float64(0.35667336773671815),
#  np.float64(0.35667336773671815),
#  np.float64(0.46016149333922),
#  np.float64(0.46016149333922),
#  np.float64(0.46016149333922),
#  np.float64(0.6144118146080179),
#  np.float64(0.6485105373461986),
#  np.float64(0.5602254275602115),
#  np.float64(0.5602254275602115),
#  np.float64(0.5602254275602115),
#  np.float64(0.5602254275602115),
#  np.float64(0.789769588049451),
#  np.float64(0.789769588049451),
#  np.float64(0.41481699724663984),
#  np.float64(0.41481699724663984),
#  np.float64(0.4645911524430356),
#  np.float64(0.4564362547161176),
#  np.float64(0.6623371117894256),
#  np.float64(0.4783509636470644),
#  np.float64(0.4991868404466273),
#  np.float64(0.5887087615445064),
#  np.float64(0.5887087615445064),
#  np.float64(0.5887087615445064),
#  np.float64(0.47434959003817223),
#  np.float64(0.47434959003817223),
#  np.float64(0.47434959003817223),
#  np.float64(0.5117912351482384),
#  np.float64(0.5117912351482384),
#  np.float64(0.40863917219313234),
#  np.float64(0.40863917219313234),
#  np.float64(0.40863917219313234),
#  np.float64(0.40863917219313234),
#  np.float64(0.40863917219313234),
#  np.float64(0.40863917219313234),
#  np.float64(0.40863917219313234),
#  np.float64(0.40863917219313234),
#  np.float64(0.40863917219313234),
#  np.float64(0.7176920922215462),
#  np.float64(0.6430233632507351),
#  np.float64(0.7118116829272908),
#  np.float64(0.4512929551352076),
#  np.float64(0.5392341904066411)]

# %%
sns.displot(y_all)
